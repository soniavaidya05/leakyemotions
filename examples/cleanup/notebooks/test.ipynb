# %%
# %load_ext autoreload

# --------------- #
# region: Imports #
import os
import sys
module_path = os.path.abspath('../../..')
if module_path not in sys.path:
  sys.path.insert(0, module_path)
# endregion   #
# --------------- #

# %%
from examples.cleanup.env import Cleanup
from examples.cleanup.agents import Agent
from examples.RPG.utils import load_config
from gem.models.grid_cells import positional_embedding
from gem.models.human_player import ModelHumanPlayer
from gem.models.iqn import iRainbowModel
from gem.utils import visual_field_sprite, image_from_array, animate

from IPython.display import clear_output

import argparse
import matplotlib.pyplot as plt
import random

import torch
import numpy as np

cfg = load_config(argparse.Namespace(config='../configs/config.yaml'))

N_AGENTS = 3
agents = []
for i in range(N_AGENTS):
  agents.append(
  Agent(cfg, appearance = cfg.agent.agent.appearance, 
        model = iRainbowModel(
        state_size= [cfg.env.channels, cfg.env.height, cfg.env.width],
        action_size= 6,
        layer_size= 128,
        epsilon= 1.0,
        #device= Union[str, torch.device],
        device = 'cpu',
        seed= 0,
        # iRainbow parameters
        num_frames= 1,
        n_step= 1,
        sync_freq=10,
        model_update_freq= 10,
        BATCH_SIZE= 32,
        BUFFER_SIZE= 4000,
        LR= .001,
        TAU= .001,
        GAMMA= .99,
        N= 32
          )
          )
  )

env = Cleanup(
  cfg, agents
)

# %%
cfg.experiment.epochs = 1000 # override the number of epochs

rewards = []
losses = 0

for epoch in range(cfg.experiment.epochs): # note that the language is not right. epoch is training. episode is the game
    # Reset the environment at the start of each epoch
        for agent in env.agents:
            agent.reset()
        random.shuffle(agents)

        done = 0 
        turn = 0
        losses = 0
        game_points = 0
        images = []

        while not done:

            turn = turn + 1
            print(f"Epoch {epoch}. Turn {turn}.")
            clear_output(wait = True)

            entities = env.get_entities_for_transition()
            # Entity transition
            for entity in entities:
                entity.transition(env)

            # Agent transition
            for agent in agents:
                if (epoch+1) % 100 == 0:
                    agent.model.epsilon = agent.model.epsilon*0.9999

                location_code = positional_embedding(agent.location, env, 3, 3)
                _image = visual_field_sprite(env.world)
                image = image_from_array(_image)
                images.append(image)

                (state,
                action,
                reward,
                next_state,
                done_
                ) = agent.transition(env)

                if turn >= cfg.experiment.max_turns or done_:
                    done = 1
                    _image = visual_field_sprite(env.world)
                    image = image_from_array(_image)
                    images.append(image)

                exp = (1, (state, action, reward, next_state, done))
                agent.episode_memory.append(exp)
                #TODO: decide on memory update procedures
                agent.model.memory.add(state.squeeze().unsqueeze(0), action, reward, next_state.squeeze().unsqueeze(0), done)

                game_points += reward

        rewards.append(game_points)
        
        # At the end of each epoch, train as long as the batch size is large enough.
        if epoch > 10:
            loss = agent.model.train_model()
            losses += loss
            
        # Calculate the average of the last 100 rewards
        if len(rewards) >= 100:
            avg_last_100_rewards = sum(rewards[-100:]) / 100
        else:
            avg_last_100_rewards = sum(rewards) / len(rewards)
        if epoch % 50 == 0:
            print(f'Epoch: {epoch} - Epsilon: {agents[0].model.epsilon} - Losses {losses} - Avg. last 100 rewards: {avg_last_100_rewards}')
            animate(
                images, filename = f"cleanup_epoch{epoch}", folder = f"{cfg.root}/examples/cleanup/data/"
            )
            losses = 0
# Out:
# Epoch: 0 - Epsilon: 1.0 - Losses 0 - Avg. last 100 rewards: 7.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 33
#      30     agent.model.epsilon = agent.model.epsilon*0.9999
#      32 location_code = positional_embedding(agent.location, env, 3, 3)
# ---> 33 _image = visual_field_sprite(env.world)
#      34 image = image_from_array(_image)
#      35 images.append(image)
#
# File ~/Documents/GitHub/agentarium/gem/utils.py:279, in visual_field_sprite(world, location, vision, tile_size)
#     277 else:
#     278     tile_appearance = world[i, j, z].sprite
# --> 279     tile_image = Image.open(tile_appearance).resize(tile_size).convert('RGBA')
#     281 tile_image_array = np.array(tile_image)
#     282 alpha = tile_image_array[:, :, 3]
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/Image.py:3318, in open(fp, mode, formats)
#    3315             raise
#    3316     return None
# -> 3318 im = _open_core(fp, filename, prefix, formats)
#    3320 if im is None and formats is ID:
#    3321     checked_formats = formats.copy()
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/Image.py:3304, in open.<locals>._open_core(fp, filename, prefix, formats)
#    3302 elif result:
#    3303     fp.seek(0)
# -> 3304     im = factory(fp, filename)
#    3305     _decompression_bomb_check(im.size)
#    3306     return im
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/ImageFile.py:137, in ImageFile.__init__(self, fp, filename)
#     135 try:
#     136     try:
# --> 137         self._open()
#     138     except (
#     139         IndexError,  # end of data
#     140         TypeError,  # end of data (ord)
#    (...)
#     143         struct.error,
#     144     ) as v:
#     145         raise SyntaxError(v) from v
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/PngImagePlugin.py:724, in PngImageFile._open(self)
#     721 cid, pos, length = self.png.read()
#     723 try:
# --> 724     s = self.png.call(cid, pos, length)
#     725 except EOFError:
#     726     break
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/PngImagePlugin.py:192, in ChunkStream.call(self, cid, pos, length)
#     189 """Call the appropriate chunk handler"""
#     191 logger.debug("STREAM %r %s %s", cid, pos, length)
# --> 192 return getattr(self, "chunk_" + cid.decode("ascii"))(pos, length)
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/PngImagePlugin.py:515, in PngStream.chunk_pHYs(self, pos, length)
#     513     msg = "Truncated pHYs chunk"
#     514     raise ValueError(msg)
# --> 515 px, py = i32(s, 0), i32(s, 4)
#     516 unit = s[8]
#     517 if unit == 1:  # meter
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/PIL/_binary.py:94, in i32be(c, o)
#      90 def i16be(c: bytes, o: int = 0) -> int:
#      91     return unpack_from(">H", c, o)[0]
# ---> 94 def i32be(c: bytes, o: int = 0) -> int:
#      95     return unpack_from(">I", c, o)[0]
#      98 # Output, le = little endian, be = big endian
#
# KeyboardInterrupt:
